# %%
import matplotlib.pyplot as plt

# Data
gender = ['unknown', 'male', 'female']
users = [13142, 7218, 4944]
new_users = [12691, 5877, 4304]
engaged_sessions = [23161, 10467, 7877]
engagement_rate = [0.564077, 0.543091, 0.63771]
engaged_sessions_per_user = [1.762365, 1.450125, 1.593244]
average_engagement_time = [439.5776, 128.2319, 208.7407]
event_count = [761771, 282504, 274254]
conversions = [93180, 65651, 35083]

# Create subplots
fig, axes = plt.subplots(2, 1, figsize=(10, 12))

# Bar chart for users
axes[0].bar(gender, users, color='b', label='Users')
axes[0].bar(gender, new_users, color='g', bottom=users, label='New Users')
axes[0].set_ylabel('Count')
axes[0].set_title('Users and New Users by Gender')
axes[0].legend()

# Pie chart for engagement rate
axes[1].pie(engagement_rate, labels=gender, autopct='%1.1f%%', startangle=90)
axes[1].set_title('Engagement Rate by Gender')

plt.tight_layout()
plt.show()

# %%
# Read the data from the CSV file
csv_file = '/Users/adityaradhakrishnan/Desktop/Promilio/CSVFiles/Traffic Aquisition.csv'
df = pd.read_csv(csv_file)

# Extract relevant data for visualization
channels = df['Session default channel group']
engaged_sessions = df['Engaged sessions']
conversions = df['Conversions']

# Create a bar plot for Engaged sessions
plt.figure(figsize=(10, 6))
plt.bar(channels, engaged_sessions, color='skyblue')
plt.xlabel('Channel Group')
plt.ylabel('Engaged Sessions')
plt.title('Engaged Sessions per Channel Group')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Create a bar plot for Conversions
plt.figure(figsize=(10, 6))
plt.bar(channels, conversions, color='lightcoral')
plt.xlabel('Channel Group')
plt.ylabel('Conversions')
plt.title('Conversions per Channel Group')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
